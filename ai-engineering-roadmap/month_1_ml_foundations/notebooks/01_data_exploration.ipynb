# %%
# Imports
import pandas as pd

# Load dataset
data = pd.read_csv("../data/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# Inspect
print(data.head())
print(data.info())
print(data['Churn'].value_counts())
